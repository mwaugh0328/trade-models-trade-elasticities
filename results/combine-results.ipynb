# %% [markdown]
# ### Combine Estimation Results
#
# This notebook reads CSV files with date stamps (e.g., `-12726`) from the results folder and combines them into a single DataFrame.

# %%
import pandas as pd
import glob
import re
from pathlib import Path

# %%
# Get all CSV files in the results folder
results_folder = Path('.')
all_csv_files = list(results_folder.glob('*.csv'))

# Filter to only include files with a date pattern (e.g., -12726)
# Pattern: filename containing a hyphen followed by digits before .csv
date_pattern = re.compile(r'-\d+(-[\w-]+)?\.csv$')
dated_files = [f for f in all_csv_files if date_pattern.search(f.name)]

print(f"Found {len(dated_files)} files with date stamps:")
for f in dated_files:
    print(f"  - {f.name}")
# Out:
# Found 10 files with date stamps:
#   - bejk-estimate-exact-12726.csv
#   - bejk-estimate-over-12726.csv
#   - ek-estimate-exact-12726.csv
#   - ek-estimate-over-12726.csv
#   - krugman-estimate-exact-12726.csv
#   - krugman-estimate-over-12726.csv
#   - melitz-estimate-exact-12726.csv
#   - melitz-estimate-exact-12926-sigma-theta.csv
#   - melitz-estimate-over-12726.csv
#   - melitz-estimate-over-12926-sigma-theta.csv

# %%
# Separate files into exact and over categories
exact_files = [f for f in dated_files if 'exact' in f.name]
over_files = [f for f in dated_files if 'over' in f.name]

print(f"Exact files ({len(exact_files)}):")
for f in exact_files:
    print(f"  - {f.name}")

print(f"\nOver files ({len(over_files)}):")
for f in over_files:
    print(f"  - {f.name}")
# Out:
# Combined 10 files into a DataFrame with 30 rows

# %%
# Read and combine EXACT files
exact_dfs = []
for file in exact_files:
    df = pd.read_csv(file)
    df['source_file'] = file.name
    exact_dfs.append(df)

exact_df = pd.concat(exact_dfs, ignore_index=True)

# Read and combine OVER files
over_dfs = []
for file in over_files:
    df = pd.read_csv(file)
    df['source_file'] = file.name
    over_dfs.append(df)

over_df = pd.concat(over_dfs, ignore_index=True)

# Set display options to show 2 decimal places
pd.set_option('display.float_format', '{:.2f}'.format)

print(f"Exact DataFrame: {len(exact_df)} rows")
print(f"Over DataFrame: {len(over_df)} rows")
# Out:
#       θ       J  p10  p90  Jpercentile  model_moment  data_moment    model  \
# 0  2.82    0.00 2.73 2.93         0.14          0.93         0.93     bejk
# 1  2.73    0.00 2.66 2.85         0.49          0.98         0.98     bejk
# 2  2.87    0.00 2.76 3.00         0.69          0.91         0.91     bejk
# 3  2.76   23.31 2.71 2.83         0.68           NaN          NaN     bejk
# 4  2.80  173.18 2.74 2.88         1.00           NaN          NaN     bejk
# 5  2.88  180.72 2.81 2.95         1.00           NaN          NaN     bejk
# 6  4.09    0.00 3.92 4.23         0.98          0.93         0.93       ek
# 7  3.94    0.00 3.81 4.08         0.80          0.98         0.98       ek
# 8  4.19    0.00 4.05 4.34         0.34          0.91         0.91       ek
# 9  4.00   10.74 3.91 4.12         0.38           NaN          NaN       ek
# 10 4.07  136.76 3.99 4.18         0.99           NaN          NaN       ek
# 11 4.18  139.25 4.09 4.31         1.00           NaN          NaN       ek
# 12 5.19    0.00 4.96 5.57         0.48          0.93         0.93  krugman
# 13 4.90    0.00 4.73 5.12         0.66          0.98         0.98  krugman
# 14 5.17    0.00 4.94 5.41         0.46          0.91         0.91  krugman
# 15 3.76 1390.47 3.56 3.92         1.00           NaN          NaN  krugman
# 16 3.49  983.90 3.34 3.60         1.00           NaN          NaN  krugman
# 17 3.82 1411.74 3.64 3.98         1.00           NaN          NaN  krugman
# 18 3.50    0.00 3.06 3.90         0.19          0.93         0.93   melitz
# 19 3.30    0.00 3.10 3.83         0.02          0.98         0.98   melitz
# 20 3.32    0.00 2.83 3.73         0.15          0.91         0.91   melitz
# 21 3.50    0.00 3.06 3.90         0.14          0.93         0.93   melitz
# 22 3.30    0.00 3.10 3.83         0.02          0.98         0.98   melitz
# 23 3.32    0.00 2.83 3.73         0.27          0.91         0.91   melitz
# 24 3.59  133.16 3.38 3.91         0.86           NaN          NaN   melitz
# 25 3.15   60.78 2.91 3.67         0.53           NaN          NaN   melitz
# 26 3.08  287.52 2.60 3.82         0.92           NaN          NaN   melitz
# 27 3.59  133.16 3.38 3.91         0.86           NaN          NaN   melitz
# 28 3.15   60.78 2.91 3.67         0.53           NaN          NaN   melitz
# 29 3.08  287.52 2.60 3.82         0.92           NaN          NaN   melitz
#
#    method  year                                  source_file  model_moment_1  \
# 0   exact  2004                bejk-estimate-exact-12726.csv             NaN
# 1   exact  2011                bejk-estimate-exact-12726.csv             NaN
# 2   exact  2017                bejk-estimate-exact-12726.csv             NaN
# 3    over  2004                 bejk-estimate-over-12726.csv            0.95
# 4    over  2011                 bejk-estimate-over-12726.csv            0.96
# 5    over  2017                 bejk-estimate-over-12726.csv            0.91
# 6   exact  2004                  ek-estimate-exact-12726.csv             NaN
# 7   exact  2011                  ek-estimate-exact-12726.csv             NaN
# 8   exact  2017                  ek-estimate-exact-12726.csv             NaN
# 9    over  2004                   ek-estimate-over-12726.csv            0.95
# 10   over  2011                   ek-estimate-over-12726.csv            0.95
# 11   over  2017                   ek-estimate-over-12726.csv            0.91
# 12  exact  2004             krugman-estimate-exact-12726.csv             NaN
# 13  exact  2011             krugman-estimate-exact-12726.csv             NaN
# 14  exact  2017             krugman-estimate-exact-12726.csv             NaN
# 15   over  2004              krugman-estimate-over-12726.csv            1.28
# 16   over  2011              krugman-estimate-over-12726.csv            1.38
# 17   over  2017              krugman-estimate-over-12726.csv            1.23
# 18  exact  2004              melitz-estimate-exact-12726.csv             NaN
# 19  exact  2011              melitz-estimate-exact-12726.csv             NaN
# 20  exact  2017              melitz-estimate-exact-12726.csv             NaN
# 21  exact  2004  melitz-estimate-exact-12926-sigma-theta.csv             NaN
# 22  exact  2011  melitz-estimate-exact-12926-sigma-theta.csv             NaN
# 23  exact  2017  melitz-estimate-exact-12926-sigma-theta.csv             NaN
# 24   over  2004               melitz-estimate-over-12726.csv            0.90
# 25   over  2011               melitz-estimate-over-12726.csv            1.03
# 26   over  2017               melitz-estimate-over-12726.csv            0.98
# 27   over  2004   melitz-estimate-over-12926-sigma-theta.csv            0.90
# 28   over  2011   melitz-estimate-over-12926-sigma-theta.csv            1.03
# 29   over  2017   melitz-estimate-over-12926-sigma-theta.csv            0.98
#
#     data_moment_1  model_moment_2  data_moment_2  model_moment_3  \
# 0             NaN             NaN            NaN             NaN
# 1             NaN             NaN            NaN             NaN
# 2             NaN             NaN            NaN             NaN
# 3            0.93            0.36           0.37            0.07
# 4            0.98            0.34           0.34            0.07
# 5            0.91            0.33           0.32            0.06
# 6             NaN             NaN            NaN             NaN
# 7             NaN             NaN            NaN             NaN
# 8             NaN             NaN            NaN             NaN
# 9            0.93            0.36           0.37            0.09
# 10           0.98            0.34           0.34            0.09
# 11           0.91            0.32           0.32            0.07
# 12            NaN             NaN            NaN             NaN
# 13            NaN             NaN            NaN             NaN
# 14            NaN             NaN            NaN             NaN
# 15           0.93            0.25           0.37            0.23
# 16           0.98            0.25           0.34            0.23
# 17           0.91            0.21           0.32            0.20
# 18            NaN             NaN            NaN             NaN
# 19            NaN             NaN            NaN             NaN
# 20            NaN             NaN            NaN             NaN
# 21            NaN             NaN            NaN             NaN
# 22            NaN             NaN            NaN             NaN
# 23            NaN             NaN            NaN             NaN
# 24           0.93            0.34           0.37            0.21
# 25           0.98            0.29           0.34            0.25
# 26           0.91            0.23           0.32            0.25
# 27           0.93            0.34           0.37            0.21
# 28           0.98            0.29           0.34            0.25
# 29           0.91            0.23           0.32            0.25
#
#     data_moment_3
# 0             NaN
# 1             NaN
# 2             NaN
# 3            0.09
# 4            0.25
# 5            0.20
# 6             NaN
# 7             NaN
# 8             NaN
# 9            0.09
# 10           0.25
# 11           0.20
# 12            NaN
# 13            NaN
# 14            NaN
# 15           0.09
# 16           0.25
# 17           0.20
# 18            NaN
# 19            NaN
# 20            NaN
# 21            NaN
# 22            NaN
# 23            NaN
# 24           0.09
# 25           0.25
# 26           0.20
# 27           0.09
# 28           0.25
# 29           0.20

# %%
# Display EXACT results
print("=== EXACT Estimation Results ===")
exact_df

# %%
# Optionally save the combined results
# exact_df.to_csv('combined-exact-results.csv', index=False, float_format='%.2f')
# over_df.to_csv('combined-over-results.csv', index=False, float_format='%.2f')

# %%
# Display OVER results
print("=== OVER Estimation Results ===")
over_df
